# %%
from pygooglenews import GoogleNews
from newsplease import NewsPlease
from nlptools import url_google_to_original

# %%
gn =  GoogleNews(lang = 'en')

query = "Huffpost+Jill+Covid"
gn_search = gn.search(query = query)['entries']

print(gn_search[0]['title'], url_google_to_original(gn_search[0['link']))

for article in gn_search:
    data = print(article['title'], url_google_to_original(article['link']))
# Out:
# First Lady Jill Biden Tests Positive For COVID-19 - HuffPost https://www.huffpost.com/entry/jill-biden-covid-positive-spokeswoman_n_64f68311e4b0c9c32ded765d
# DeSantis Rejects Meeting With Biden During President’s Florida Visit In Wake Of Idalia - HuffPost https://www.huffpost.com/entry/biden-tells-hurricane-idalias-florida-victims-your-nation-has-your-back_n_64f3aea8e4b0fe066b1812f7
# The GOP Is Over Its War On 'Woke' - HuffPost https://www.huffpost.com/entry/republican-presidential-candidates-woke-iowa-ron-desantis-vivek-ramaswamy_n_64dfd0c4e4b0dd561030ebce
# U.S. Suicides Hit All-Time High In 2022 - HuffPost https://www.huffpost.com/entry/us-suicides-hit-an-all-time-high-last-year_n_64d65a27e4b0e993d817c9bb
# Ex-Trump Attorney Says Trump's 'Irrefutable' Fraud Report Could Backfire Badly - Yahoo News https://news.yahoo.com/ex-trump-attorney-says-trumps-130834803.html
# ...
