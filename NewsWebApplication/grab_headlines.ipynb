# %%
text = """ Atlanta-area prosecutors investigating efforts to overturn the 2020 election results in Georgia are in possession of text messages and emails directly connecting members of Donald Trump’s legal team to the early January 2021 voting system breach in Coffee County, sources tell CNN.
Fulton County District Attorney Fani Willis is expected to seek charges against more than a dozen individuals when her team presents its case before a grand jury next week. Several individuals involved in the voting systems breach in Coffee County are among those who may face charges in the sprawling criminal probe.
Investigators in the Georgia criminal probe have long suspected the breach was not an organic effort sprung from sympathetic Trump supporters in rural and heavily Republican Coffee County – a county Trump won by nearly 70% of the vote. They have gathered evidence indicating it was a top-down push by Trump’s team to access sensitive voting software, according to people familiar with the situation.
Trump allies attempted to access voting systems after the 2020 election as part of the broader push to produce evidence that could back up the former president’s baseless claims of widespread fraud.
While Trump’s January 2021 call to Georgia Secretary of State Brad Raffensperger and effort to put forward fake slates of electors have long been considered key pillars of Willis’ criminal probe, the voting system breach in Coffee County quietly emerged as an area of focus for investigators roughly one year ago. Since then, new evidence has slowly been uncovered about the role of Trump’s attorneys, the operatives they hired and how the breach, as well as others like it in other key states, factored into broader plans for overturning the election.
Together, the text messages and other court documents show how Trump lawyers and a group of hired operatives sought to access Coffee County’s voting systems in the days before January 6, 2021, as the former president’s allies continued a desperate hunt for any evidence of widespread fraud they could use to delay certification of Joe Biden’s electoral victory.
Last year, a former Trump official testified under oath to the House January 6 select committee that plans to access voting systems in Georgia were discussed in meetings at the White House, including during an Oval Office meeting on December 18, 2020, that included Trump.
Six days before pro-Trump operatives gained unauthorized access to voting systems, the local elections official who allegedly helped facilitate the breach sent a “written invitation” to attorneys working for Trump, according to text messages obtained by CNN.
Investigators have scrutinized the actions of various individuals who were involved, including Misty Hampton, a former Coffee County elections official who authored the letter of invitation referenced in text messages and other documents that have been turned over to prosecutors, multiple sources told CNN.
They have also examined the involvement of Trump’s then attorney Rudy Giuliani – who was informed last year he was a target in the Fulton County investigation – and fellow Trump lawyer Sidney Powell as part of their probe, according to people familiar with the matter.
A spokesperson for Willis’ office declined to comment.
The letter of invitation was shared with attorneys and an investigator working with Giuliani at the time, the text messages obtained by CNN show.
A ‘written invitation’ to access voting systems
On January 1, 2021 – days ahead of the January 7 voting systems breach – Katherine Friess – an attorney working with Giuliani, Sidney Powell and other Trump allies shared a “written invitation” to examine voting systems in Coffee County with a group of Trump allies.
That group included members of Sullivan Strickler, a firm hired by Trump’s attorneys to examine voting systems in the small, heavily Republican Georgia county, according to text messages obtained by CNN.
That same day, Friess sent a “Letter of invitation to Coffee County, Georgia” to former NYPD Police Commissioner Bernie Kerik, who was working with Giuliani to find evidence that would back up their baseless claims of potential widespread voter fraud, according to court documents filed as part of an ongoing civil case.
Friess then notified operatives who carried out the Coffee County breach and others working directly with Giuliani that Trump’s team had secured written permission, the texts show.
CNN has not reviewed the substance of the invitation letter itself, only communications that confirm it was provided to Friess, Kerik and Sullivan Strickler employees.
Friess could not be reached for comment.
The messages and documents appear to link Giuliani to the Coffee County breach, while shedding light on another channel of communication between pro-Trump attorneys and the battleground state operatives who worked together to provide unauthorized individuals access to sensitive voting equipment.
“Rudy Giuliani had nothing to do with this,” said Robert Costello, Giuliani’s attorney. “You can’t attach Rudy Giuliani to Sidney Powell’s crackpot idea.”
“Just landed back in DC with the Mayor huge things starting to come together!” an employee from the firm Sullivan Strickler, which was hired by Sidney Powell to examine voting systems in Coffee County, wrote in a group chat with other colleagues on January 1.
Former New York Mayor Giuliani was consistently referred to as “the Mayor,” in other texts sent by the same individual and others at the time.
“Most immediately, we were just granted access – by written invitation! – to Coffee County’s systems. Yay!” the text reads.
Breaking into Coffee County
Shortly after Election Day, Hampton – still serving as the top election official for Coffee County – warned during a state election board meeting that Dominion voting machines could “very easily” be manipulated to flip votes from one candidate to another. It’s a claim that has been repeatedly debunked.
But the Trump campaign officials took notice and reached out to Hampton that same day. “I would like to obtain as much information as possible,” a Trump campaign staffer emailed Hampton at the time, according to documents released as part of a public records request and first reported by the Washington Post.
In early December, Hampton then delayed certification of Joe Biden’s win in Georgia by refusing to validate the recount results by a key deadline. Coffee County was the only county in Georgia that failed to certify its election results due to issues raised by Hampton at the time.
Hampton also posted a video online claiming to expose problems with the county’s Dominion voting system. That video was used by Trump’s lawyers, including Giuliani, as part of their push to convince legislators from multiple states that there was evidence the 2020 election results were tainted by voting system issues.
Text messages and other documents obtained by CNN show Trump allies were seeking access to Coffee County’s voting system by mid-December amid increasing demands for proof of widespread election fraud.
Coffee County was specifically cited in draft executive orders for seizing voting machines that were presented to Trump on December 18, 2020, during a chaotic Oval Office meeting, CNN has reported. During that same meeting, Giuliani alluded to a plan to gain “voluntary access” to machines in Georgia, according to testimony from him and others before the House January 6 committee.
Days later, Hampton shared the written invitation to access the county’s election office with a Trump lawyer, text messages obtained by CNN show. She and another location elections official, Cathy Latham, allegedly helped Trump operatives gain access to the county’s voting systems, according to documents, testimony and surveillance video produced as part of a long-running civil lawsuit focused on election security in Georgia.
Latham, who also served as a fake elector from Georgia after the 2020 election, has come under scrutiny for her role in the Coffee County breach after surveillance video showed she allowed unauthorized outsiders to spend hours examining voting systems there."""

# %%
import spacy
import spacy_experimental

nlp = spacy.load('en_coreference_web_trf')
doc = nlp("The cats were startled by the  dogs")

# %%
print(doc.spans)
# Out:
# {}

# %%
def posprocess(sentence):
    tokenized = word_tokenize(sentence)
    pos_tagged = pos_tag(tokenized)
    return pos_tagged

def nouns(pos_tagged):
    is_noun = lambda pos: pos[:2] == 'NN'
    return [word for (word, pos) in pos_tagged if is_noun(pos)]




class Title:
    def __init__(self, title):
        self.data = title
        self.pos = posprocess(self.data)
        self.nouns = nouns(self.pos)


class GN_Article:
    def __init__(self, title, url):
        self.title, self.publisher = self.parse_title_publisher(title)
        self.url = url

    def parse_title_publisher(self, title):
        
        def find_split(title):
            i = 1
            while i <= len(title):
                if title[-i] == '-':
                    return len(title) - i
                i += 1

        split_at = find_split(title)

        return Title(title[:split_at].strip()), title[split_at + 1:].strip()

    def __eq__(self, other):
        return self.url == other.url

    def __repr__(self) -> str:
        return f"{self.publisher}: {self.title.data}"

def grabHeadlines():
    publisher_country = ['US', 'UK']
    topics            = ['WORLD', 'NATION']

    news = []
    for country in publisher_country: 
        gn =  GoogleNews(lang = 'en', country = country)

        for topic in topics: 
            articles = gn.topic_headlines(topic)["entries"]
            for article in articles:
                data = GN_Article(article['title'], url_google_to_original(article['link']))
                
                if data not in news:
                    news.append(data)
    
    return news

# %%
news = grabHeadlines()

# %%
article = NewsPlease.from_url(news[1].url)

# %% [markdown]
# # SpaCy

# %%
# https://github.com/richardpaulhudson/coreferee#model-performance

import spacy
nlp = spacy.load('en_core_web_trf')
nlp.add_pipe('coreferee')
doc = nlp("Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.")
doc._.coref_chains.print()
# Out:
# Collecting en-core-web-trf==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.5.0/en_core_web_trf-3.5.0-py3-none-any.whl (460.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.3/460.3 MB 5.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from en-core-web-trf==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-transformers<1.3.0,>=1.2.0.dev0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from en-core-web-trf==3.5.0) (1.2.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (8.1.11)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (1.10.12)
# Requirement already satisfied: jinja2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.3.0)
# Requirement already satisfied: transformers<4.31.0,>=3.4.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (4.25.1)
# Requirement already satisfied: torch>=1.8.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (2.0.1)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (0.1.1)
# Requirement already satisfied: filelock in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (3.12.2)
# Requirement already satisfied: sympy in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (1.12)
# Requirement already satisfied: networkx in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (2.0.0)
# Requirement already satisfied: wheel in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (0.41.1)
# Requirement already satisfied: cmake in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (3.27.1)
# Requirement already satisfied: lit in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (16.0.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (0.16.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (0.13.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-trf==3.5.0) (2.1.3)
# Requirement already satisfied: fsspec in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers<4.31.0,>=3.4.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (2023.6.0)
# Requirement already satisfied: mpmath>=0.19 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from sympy->torch>=1.8.0->spacy-transformers<1.3.0,>=1.2.0.dev0->en-core-web-trf==3.5.0) (1.3.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.7 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from en-core-web-lg==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.11)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.12)
# Requirement already satisfied: jinja2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.1.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_trf' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.6.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 7
#       4 # https://github.com/richardpaulhudson/coreferee#model-performance
#       6 import spacy
# ----> 7 nlp = spacy.load('en_core_web_trf')
#       8 nlp.add_pipe('coreferee')
#       9 doc = nlp("Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.")
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#      42     vocab (Vocab): A Vocab object. If True, a vocab is created.
#      43     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#      44         pipes will be loaded but they won't be run unless you explicitly
#      45         enable them by calling nlp.enable_pipe.
#      46     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
#      47         pipes will be disabled (but can be enabled later using nlp.enable_pipe).
#      48     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#      49         components won't be loaded.
#      50     config (Dict[str, Any] / Config): Config overrides as nested dict or dict
# ---> 51         keyed by section values in dot notation.
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
#      54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#    (...)
#      60         config=config,
#      61     )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     442 def load_model_from_package(
#     443     name: str,
#     444     *,
#    (...)
#     449     config: Union[Dict[str, Any], Config] = SimpleFrozenDict(),
#     450 ) -> "Language":
#     451     """Load a model from an installed package.
#     452
#     453     name (str): The package name.
#     454     vocab (Vocab / True): Optional vocab to pass in on initialization. If True,
#     455         a new Vocab object will be created.
#     456     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#     457         pipes will be loaded but they won't be run unless you explicitly
#     458         enable them by calling nlp.enable_pipe.
#     459     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
#     460         pipes will be disabled (and can be enabled using `nlp.enable_pipe`).
#     461     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#     462         components won't be loaded.
#     463     config (Dict[str, Any] / Config): Config overrides as nested dict or dict
#     464         keyed by section values in dot notation.
# --> 465     RETURNS (Language): The loaded nlp object.
#     466     """
#     467     cls = importlib.import_module(name)
#     468     return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     499 if not model_path.exists():
#     500     raise IOError(Errors.E052.format(path=model_path))
# --> 501 if not meta:
#     502     meta = get_model_meta(model_path)
#     503 config_path = model_path / "config.cfg"
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/en_core_web_trf/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not config_path or not config_path.is_file():
#     681     raise IOError(Errors.E053.format(path=config_path, name="config file"))
# --> 682 return config.from_disk(
#     683     config_path, overrides=overrides, interpolate=interpolate
#     684 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:539, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     517 def load_model_from_config(
#     518     config: Union[Dict[str, Any], Config],
#     519     *,
#    (...)
#     526     validate: bool = True,
#     527 ) -> "Language":
#     528     """Create an nlp object from a config. Expects the full config file including
#     529     a section "nlp" containing the settings for the nlp object.
#     530
#     531     name (str): Package name or model path.
#     532     meta (Dict[str, Any]): Optional model meta.
#     533     vocab (Vocab / True): Optional vocab to pass in on initialization. If True,
#     534         a new Vocab object will be created.
#     535     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#     536         pipes will be loaded but they won't be run unless you explicitly
#     537         enable them by calling nlp.enable_pipe.
#     538     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
# --> 539         pipes will be disabled (and can be enabled using `nlp.enable_pipe`).
#     540     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#     541         components won't be loaded.
#     542     auto_fill (bool): Whether to auto-fill config with missing defaults.
#     543     validate (bool): Whether to show config validation errors.
#     544     RETURNS (Language): The loaded nlp object.
#     545     """
#     546     if "nlp" not in config:
#     547         raise ValueError(Errors.E985.format(config=config))
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:587, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     581 def resolve_dot_names(
#     582     config: Config, dot_names: List[Optional[str]]
#     583 ) -> Tuple[Any, ...]:
#     584     """Resolve one or more "dot notation" names, e.g. corpora.train.
#     585     The paths could point anywhere into the config, so we don't know which
#     586     top-level section we'll be looking within.
# --> 587
#     588     We resolve the whole top-level section, although we could resolve less --
#     589     we could find the lowest part of the tree.
#     590     """
#     591     # TODO: include schema?
#     592     resolved = {}
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:1847, in from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1845     for name, proc in source_nlps[model].pipeline:
#    1846         if source_name in getattr(proc, "listening_components", []):
# -> 1847             source_nlps[model].replace_listeners(
#    1848                 name, source_name, pipe_cfg["replace_listeners"]
#    1849             )
#    1850             listeners_replaced = True
#    1851 with warnings.catch_warnings():
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:814, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     810     pipe_component, factory_name = self.create_pipe_from_source(
#     811         factory_name, source, name=name
#     812     )
#     813 else:
# --> 814     pipe_component = self.create_pipe(
#     815         factory_name,
#     816         name=name,
#     817         config=config,
#     818         raw_config=raw_config,
#     819         validate=validate,
#     820     )
#     821 pipe_index = self._get_pipe_index(before, after, first, last)
#     822 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:702, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     699 cfg = {factory_name: config}
#     700 # We're calling the internal _fill here to avoid constructing the
#     701 # registered functions twice
# --> 702 resolved = registry.resolve(cfg, validate=validate)
#     703 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     704 filled = Config(filled)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:756, in registry.resolve(cls, config, schema, overrides, validate)
#     747 @classmethod
#     748 def resolve(
#     749     cls,
#    (...)
#     754     validate: bool = True,
#     755 ) -> Dict[str, Any]:
# --> 756     resolved, _ = cls._make(
#     757         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     758     )
#     759     return resolved
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:805, in registry._make(cls, config, schema, overrides, resolve, validate)
#     803 if not is_interpolated:
#     804     config = Config(orig_config).interpolate()
# --> 805 filled, _, resolved = cls._fill(
#     806     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     807 )
#     808 filled = Config(filled, section_order=section_order)
#     809 # Check that overrides didn't include invalid properties not in config
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:860, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     858     schema.__fields__[key] = copy_model_field(field, Any)
#     859 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 860 filled[key], validation[v_key], final[key] = cls._fill(
#     861     value,
#     862     promise_schema,
#     863     validate=validate,
#     864     resolve=resolve,
#     865     parent=key_parent,
#     866     overrides=overrides,
#     867 )
#     868 reg_name, func_name = cls.get_constructor(final[key])
#     869 args, kwargs = cls.parse_args(final[key])
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:877, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     874     getter = cls.get(reg_name, func_name)
#     875     # We don't want to try/except this and raise our own error
#     876     # here, because we want the traceback if the function fails.
# --> 877     getter_result = getter(*args, **kwargs)
#     878 else:
#     879     # We're not resolving and calling the function, so replace
#     880     # the getter_result with a Promise class
#     881     getter_result = Promise(
#     882         registry=reg_name, name=func_name, args=args, kwargs=kwargs
#     883     )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/architectures.py:234, in create_TransformerModel_v3(name, get_spans, tokenizer_config, transformer_config, mixed_precision, grad_scaler_config)
#     199 @registry.architectures.register("spacy-transformers.TransformerModel.v3")
#     200 def create_TransformerModel_v3(
#     201     name: str,
#    (...)
#     206     grad_scaler_config: dict = {},
#     207 ) -> Model[List[Doc], "FullTransformerBatch"]:
#     208     """Pretrained transformer model that can be finetuned for downstream tasks.
#     209
#     210     name (str): Name of the pretrained Huggingface model to use.
#    (...)
#     232         `growth_interval` steps.
#     233     """
# --> 234     model = TransformerModel(
#     235         name,
#     236         get_spans,
#     237         tokenizer_config,
#     238         transformer_config,
#     239         mixed_precision,
#     240         grad_scaler_config,
#     241     )
#     242     return model
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/transformer_model.py:45, in TransformerModel.__init__(self, name, get_spans, tokenizer_config, transformer_config, mixed_precision, grad_scaler_config)
#      34 """
#      35 get_spans (Callable[[List[Doc]], List[Span]]):
#      36     A function to extract spans from the batch of Doc objects.
#    (...)
#      42 transformer_config (dict): Settings to pass to the transformers forward pass.
#      43 """
#      44 hf_model = HFObjects(None, None, None, tokenizer_config, transformer_config)
# ---> 45 wrapper = HFWrapper(
#      46     hf_model,
#      47     convert_inputs=_convert_transformer_inputs,
#      48     convert_outputs=_convert_transformer_outputs,
#      49     mixed_precision=mixed_precision,
#      50     grad_scaler_config=grad_scaler_config,
#      51 )
#      52 super().__init__(
#      53     "transformer",
#      54     forward,
#    (...)
#      66     },
#      67 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/hf_wrapper.py:53, in HFWrapper(hf_model, convert_inputs, convert_outputs, mixed_precision, grad_scaler_config, config_cls, model_cls, tokenizer_cls)
#      45 if convert_outputs is None:
#      46     convert_outputs = convert_pytorch_default_outputs
#      48 return Model(
#      49     "hf-pytorch",
#      50     pt_forward,
#      51     attrs={"convert_inputs": convert_inputs, "convert_outputs": convert_outputs},
#      52     shims=[
# ---> 53         HFShim(
#      54             hf_model,
#      55             mixed_precision=mixed_precision,
#      56             grad_scaler_config=grad_scaler_config,
#      57             config_cls=config_cls,
#      58             model_cls=model_cls,
#      59             tokenizer_cls=tokenizer_cls,
#      60         )
#      61     ],
#      62     dims={"nI": None, "nO": None},
#      63 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/hf_shim.py:46, in HFShim.__init__(self, model, config, optimizer, mixed_precision, grad_scaler_config, config_cls, model_cls, tokenizer_cls)
#      38 if "enabled" not in grad_scaler_config:
#      39     grad_scaler_config["enabled"] = mixed_precision
#      41 super().__init__(
#      42     model.transformer,
#      43     config,
#      44     optimizer,
#      45     mixed_precision,
# ---> 46     grad_scaler=PyTorchGradScaler(**grad_scaler_config),
#      47 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/thinc/shims/pytorch_grad_scaler.py:54, in PyTorchGradScaler.__init__(self, enabled, init_scale, backoff_factor, growth_factor, growth_interval)
#      51 self._backoff_factor = backoff_factor
#      52 self._growth_interval = growth_interval
# ---> 54 self._growth_tracker = torch.full((1,), 0, dtype=torch.int)
#      55 self._scale = torch.full((1,), init_scale)
#      56 self._found_inf = False
#
# AttributeError: 'NoneType' object has no attribute 'full'
# Job "globalNews (trigger: cron[minute='0,20,40'], next run at: 2023-08-11 13:40:00 CEST)" raised an exception
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/NewsWebApplication/opennews/jobs.py", line 51, in globalNews
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/scoping.py", line 552, in commit
#     return self._proxied.commit()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1920, in commit
#     trans.commit(_to_root=True)
#   File "<string>", line 2, in commit
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1236, in commit
#     self._prepare_impl()
#   File "<string>", line 2, in _prepare_impl
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1211, in _prepare_impl
#     self.session.flush()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4163, in flush
#     self._flush(objects)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4298, in _flush
#     with util.safe_reraise():
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4259, in _flush
#     flush_context.execute()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1226, in _emit_insert_statements
#     result = connection.execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO article (url, publisher, title, lead, maintext, date_published, event_id) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('https://apnews.com/article/hawaii-fires-maui-lahaina-sirens-c0f3cc5c7718bd41dd54d38479fb29b2', 'com', 'At least 55 people died on Maui. Residents had little warning before wildfires overtook a town', 'lead', 'LAHAINA, Hawaii (AP) — Maui residents who made desperate escapes from oncoming flames, some on foot, asked why Hawaii’s famous emergency warning syst ... (7271 characters truncated) ... Bend, Oregon; Bobby Caina Calvan and Beatrice Dupuy in New York; Chris Megerian in Salt Lake City; and Audrey McAvoy in Wailuku, Hawaii, contributed.', '2023-08-11 05:46:46.000000', None)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Job "globalNews (trigger: cron[minute='0,20,40'], next run at: 2023-08-11 14:00:00 CEST)" raised an exception
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/NewsWebApplication/opennews/jobs.py", line 51, in globalNews
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/scoping.py", line 552, in commit
#     return self._proxied.commit()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1920, in commit
#     trans.commit(_to_root=True)
#   File "<string>", line 2, in commit
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1236, in commit
#     self._prepare_impl()
#   File "<string>", line 2, in _prepare_impl
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1211, in _prepare_impl
#     self.session.flush()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4163, in flush
#     self._flush(objects)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4298, in _flush
#     with util.safe_reraise():
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4259, in _flush
#     flush_context.execute()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1226, in _emit_insert_statements
#     result = connection.execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO article (url, publisher, title, lead, maintext, date_published, event_id) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('https://apnews.com/article/hawaii-fires-maui-lahaina-sirens-c0f3cc5c7718bd41dd54d38479fb29b2', 'com', 'At least 55 people died on Maui. Residents had little warning before wildfires overtook a town', 'lead', 'LAHAINA, Hawaii (AP) — Maui residents who made desperate escapes from oncoming flames, some on foot, asked why Hawaii’s famous emergency warning syst ... (7271 characters truncated) ... Bend, Oregon; Bobby Caina Calvan and Beatrice Dupuy in New York; Chris Megerian in Salt Lake City; and Audrey McAvoy in Wailuku, Hawaii, contributed.', '2023-08-11 05:46:46.000000', None)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Job "globalNews (trigger: cron[minute='0,20,40'], next run at: 2023-08-11 14:20:00 CEST)" raised an exception
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
# ...
#     self.session.flush()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4163, in flush
#     self._flush(objects)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4298, in _flush
#     with util.safe_reraise():
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4259, in _flush
#     flush_context.execute()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1226, in _emit_insert_statements
#     result = connection.execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO article (url, publisher, title, lead, maintext, date_published, event_id) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('https://apnews.com/article/hawaii-fires-maui-lahaina-sirens-c0f3cc5c7718bd41dd54d38479fb29b2', 'com', 'At least 55 people died on Maui. Residents had little warning before wildfires overtook a town', 'lead', 'LAHAINA, Hawaii (AP) — Hawaii emergency management records show no indication that warning sirens sounded before people ran for their lives from wild ... (6990 characters truncated) ... overage receives support from several private foundations. See more about AP’s climate initiative here. The AP is solely responsible for all content.', '2023-08-11 05:46:46.000000', None)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Job "globalNews (trigger: cron[minute='0,20,40'], next run at: 2023-08-11 22:40:00 CEST)" raised an exception
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/NewsWebApplication/opennews/jobs.py", line 51, in globalNews
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/scoping.py", line 552, in commit
#     return self._proxied.commit()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1920, in commit
#     trans.commit(_to_root=True)
#   File "<string>", line 2, in commit
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1236, in commit
#     self._prepare_impl()
#   File "<string>", line 2, in _prepare_impl
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1211, in _prepare_impl
#     self.session.flush()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4163, in flush
#     self._flush(objects)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4298, in _flush
#     with util.safe_reraise():
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4259, in _flush
#     flush_context.execute()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1226, in _emit_insert_statements
#     result = connection.execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO article (url, publisher, title, lead, maintext, date_published, event_id) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('https://www.foxnews.com/politics/ag-garland-appoints-hunter-biden-investigator-david-weiss-special-counsel', 'foxnews', 'AG Garland appoints Hunter Biden investigator David Weiss special counsel', 'lead', 'Attorney General Merrick Garland on Friday appointed U.S. Attorney David Weiss a special counsel in the Hunter Biden probe, as well as any other matt ... (5475 characters truncated) ...  Main Justice and this investigation as well, which is at a minimum politically expedient for him."\nThe Associated Press contributed to this report.', '2023-08-11 12:28:30.000000', None)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Job "globalNews (trigger: cron[minute='0,20,40'], next run at: 2023-08-11 23:00:00 CEST)" raised an exception
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/NewsWebApplication/opennews/jobs.py", line 51, in globalNews
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/scoping.py", line 552, in commit
#     return self._proxied.commit()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1920, in commit
#     trans.commit(_to_root=True)
#   File "<string>", line 2, in commit
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1236, in commit
#     self._prepare_impl()
#   File "<string>", line 2, in _prepare_impl
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py", line 139, in _go
#     ret_value = fn(self, *arg, **kw)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 1211, in _prepare_impl
#     self.session.flush()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4163, in flush
#     self._flush(objects)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4298, in _flush
#     with util.safe_reraise():
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 147, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4259, in _flush
#     flush_context.execute()
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1226, in _emit_insert_statements
#     result = connection.execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1412, in execute
#     return meth(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 483, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1635, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1844, in _execute_context
#     return self._exec_single_context(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1984, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2339, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1965, in _exec_single_context
#     self.dialect.do_execute(
#   File "/home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 921, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO article (url, publisher, title, lead, maintext, date_published, event_id) VALUES (?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('https://www.nytimes.com/2023/08/11/technology/sam-bankman-fried-jail.html', 'nytimes', 'Sam Bankman-Fried to Be Sent to Jail After Judge Revokes Bail', 'lead', 'Mr. Bankman-Fried’s lawyer said in court that he intended to appeal.\nThe courtroom scene was the latest development in one of the most stunning corp ... (1631 characters truncated) ... he Press and a documentarian making a film about Mr. Bankman-Fried each submitted court filings raising First Amendment concerns about the gag order.', '2023-08-11 19:31:19.000000', None)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# https://spacy.io/usage

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
from pprint import pprint

# %%
text = article.maintext
doc = nlp(text)

# %%
items = [x.text for x in doc.ents]
Counter(items).most_common(3)
# Out:
# [('Niger', 8), ('Wagner', 6), ('Nigeria', 4)]

# %%
import spacy
nlp = spacy.load('en_core_web_trf')
nlp.add_pipe('coreferee')
doc = nlp("Although he was very busy with his work, Peter had had enough of it. He and his wife decided they needed a holiday. They travelled to Spain because they loved the country very much.")
doc._.coref_chains.print()
# Out:
# /home/luisgarchi/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_lg' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.6.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 3
#       1 import spacy
#       2 nlp = spacy.load('en_core_web_lg')
# ----> 3 nlp = spacy.load('en_core_web_trf')
#       4 nlp.add_pipe('coreferee')
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#      42     vocab (Vocab): A Vocab object. If True, a vocab is created.
#      43     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#      44         pipes will be loaded but they won't be run unless you explicitly
#      45         enable them by calling nlp.enable_pipe.
#      46     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
#      47         pipes will be disabled (but can be enabled later using nlp.enable_pipe).
#      48     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#      49         components won't be loaded.
#      50     config (Dict[str, Any] / Config): Config overrides as nested dict or dict
# ---> 51         keyed by section values in dot notation.
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
#      54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#    (...)
#      60         config=config,
#      61     )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     442 def load_model_from_package(
#     443     name: str,
#     444     *,
#    (...)
#     449     config: Union[Dict[str, Any], Config] = SimpleFrozenDict(),
#     450 ) -> "Language":
#     451     """Load a model from an installed package.
#     452
#     453     name (str): The package name.
#     454     vocab (Vocab / True): Optional vocab to pass in on initialization. If True,
#     455         a new Vocab object will be created.
#     456     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#     457         pipes will be loaded but they won't be run unless you explicitly
#     458         enable them by calling nlp.enable_pipe.
#     459     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
#     460         pipes will be disabled (and can be enabled using `nlp.enable_pipe`).
#     461     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#     462         components won't be loaded.
#     463     config (Dict[str, Any] / Config): Config overrides as nested dict or dict
#     464         keyed by section values in dot notation.
# --> 465     RETURNS (Language): The loaded nlp object.
#     466     """
#     467     cls = importlib.import_module(name)
#     468     return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     499 if not model_path.exists():
#     500     raise IOError(Errors.E052.format(path=model_path))
# --> 501 if not meta:
#     502     meta = get_model_meta(model_path)
#     503 config_path = model_path / "config.cfg"
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/en_core_web_trf/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not config_path or not config_path.is_file():
#     681     raise IOError(Errors.E053.format(path=config_path, name="config file"))
# --> 682 return config.from_disk(
#     683     config_path, overrides=overrides, interpolate=interpolate
#     684 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:539, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     517 def load_model_from_config(
#     518     config: Union[Dict[str, Any], Config],
#     519     *,
#    (...)
#     526     validate: bool = True,
#     527 ) -> "Language":
#     528     """Create an nlp object from a config. Expects the full config file including
#     529     a section "nlp" containing the settings for the nlp object.
#     530
#     531     name (str): Package name or model path.
#     532     meta (Dict[str, Any]): Optional model meta.
#     533     vocab (Vocab / True): Optional vocab to pass in on initialization. If True,
#     534         a new Vocab object will be created.
#     535     disable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to disable. Disabled
#     536         pipes will be loaded but they won't be run unless you explicitly
#     537         enable them by calling nlp.enable_pipe.
#     538     enable (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to enable. All other
# --> 539         pipes will be disabled (and can be enabled using `nlp.enable_pipe`).
#     540     exclude (Union[str, Iterable[str]]): Name(s) of pipeline component(s) to exclude. Excluded
#     541         components won't be loaded.
#     542     auto_fill (bool): Whether to auto-fill config with missing defaults.
#     543     validate (bool): Whether to show config validation errors.
#     544     RETURNS (Language): The loaded nlp object.
#     545     """
#     546     if "nlp" not in config:
#     547         raise ValueError(Errors.E985.format(config=config))
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/util.py:587, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     581 def resolve_dot_names(
#     582     config: Config, dot_names: List[Optional[str]]
#     583 ) -> Tuple[Any, ...]:
#     584     """Resolve one or more "dot notation" names, e.g. corpora.train.
#     585     The paths could point anywhere into the config, so we don't know which
#     586     top-level section we'll be looking within.
# --> 587
#     588     We resolve the whole top-level section, although we could resolve less --
#     589     we could find the lowest part of the tree.
#     590     """
#     591     # TODO: include schema?
#     592     resolved = {}
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:1847, in from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1845     for name, proc in source_nlps[model].pipeline:
#    1846         if source_name in getattr(proc, "listening_components", []):
# -> 1847             source_nlps[model].replace_listeners(
#    1848                 name, source_name, pipe_cfg["replace_listeners"]
#    1849             )
#    1850             listeners_replaced = True
#    1851 with warnings.catch_warnings():
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:814, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     810     pipe_component, factory_name = self.create_pipe_from_source(
#     811         factory_name, source, name=name
#     812     )
#     813 else:
# --> 814     pipe_component = self.create_pipe(
#     815         factory_name,
#     816         name=name,
#     817         config=config,
#     818         raw_config=raw_config,
#     819         validate=validate,
#     820     )
#     821 pipe_index = self._get_pipe_index(before, after, first, last)
#     822 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy/language.py:702, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     699 cfg = {factory_name: config}
#     700 # We're calling the internal _fill here to avoid constructing the
#     701 # registered functions twice
# --> 702 resolved = registry.resolve(cfg, validate=validate)
#     703 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     704 filled = Config(filled)
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:756, in registry.resolve(cls, config, schema, overrides, validate)
#     747 @classmethod
#     748 def resolve(
#     749     cls,
#    (...)
#     754     validate: bool = True,
#     755 ) -> Dict[str, Any]:
# --> 756     resolved, _ = cls._make(
#     757         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     758     )
#     759     return resolved
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:805, in registry._make(cls, config, schema, overrides, resolve, validate)
#     803 if not is_interpolated:
#     804     config = Config(orig_config).interpolate()
# --> 805 filled, _, resolved = cls._fill(
#     806     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     807 )
#     808 filled = Config(filled, section_order=section_order)
#     809 # Check that overrides didn't include invalid properties not in config
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:860, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     858     schema.__fields__[key] = copy_model_field(field, Any)
#     859 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 860 filled[key], validation[v_key], final[key] = cls._fill(
#     861     value,
#     862     promise_schema,
#     863     validate=validate,
#     864     resolve=resolve,
#     865     parent=key_parent,
#     866     overrides=overrides,
#     867 )
#     868 reg_name, func_name = cls.get_constructor(final[key])
#     869 args, kwargs = cls.parse_args(final[key])
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/confection/__init__.py:877, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     874     getter = cls.get(reg_name, func_name)
#     875     # We don't want to try/except this and raise our own error
#     876     # here, because we want the traceback if the function fails.
# --> 877     getter_result = getter(*args, **kwargs)
#     878 else:
#     879     # We're not resolving and calling the function, so replace
#     880     # the getter_result with a Promise class
#     881     getter_result = Promise(
#     882         registry=reg_name, name=func_name, args=args, kwargs=kwargs
#     883     )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/architectures.py:234, in create_TransformerModel_v3(name, get_spans, tokenizer_config, transformer_config, mixed_precision, grad_scaler_config)
#     199 @registry.architectures.register("spacy-transformers.TransformerModel.v3")
#     200 def create_TransformerModel_v3(
#     201     name: str,
#    (...)
#     206     grad_scaler_config: dict = {},
#     207 ) -> Model[List[Doc], "FullTransformerBatch"]:
#     208     """Pretrained transformer model that can be finetuned for downstream tasks.
#     209
#     210     name (str): Name of the pretrained Huggingface model to use.
#    (...)
#     232         `growth_interval` steps.
#     233     """
# --> 234     model = TransformerModel(
#     235         name,
#     236         get_spans,
#     237         tokenizer_config,
#     238         transformer_config,
#     239         mixed_precision,
#     240         grad_scaler_config,
#     241     )
#     242     return model
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/transformer_model.py:45, in TransformerModel.__init__(self, name, get_spans, tokenizer_config, transformer_config, mixed_precision, grad_scaler_config)
#      34 """
#      35 get_spans (Callable[[List[Doc]], List[Span]]):
#      36     A function to extract spans from the batch of Doc objects.
#    (...)
#      42 transformer_config (dict): Settings to pass to the transformers forward pass.
#      43 """
#      44 hf_model = HFObjects(None, None, None, tokenizer_config, transformer_config)
# ---> 45 wrapper = HFWrapper(
#      46     hf_model,
#      47     convert_inputs=_convert_transformer_inputs,
#      48     convert_outputs=_convert_transformer_outputs,
#      49     mixed_precision=mixed_precision,
#      50     grad_scaler_config=grad_scaler_config,
#      51 )
#      52 super().__init__(
#      53     "transformer",
#      54     forward,
#    (...)
#      66     },
#      67 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/hf_wrapper.py:53, in HFWrapper(hf_model, convert_inputs, convert_outputs, mixed_precision, grad_scaler_config, config_cls, model_cls, tokenizer_cls)
#      45 if convert_outputs is None:
#      46     convert_outputs = convert_pytorch_default_outputs
#      48 return Model(
#      49     "hf-pytorch",
#      50     pt_forward,
#      51     attrs={"convert_inputs": convert_inputs, "convert_outputs": convert_outputs},
#      52     shims=[
# ---> 53         HFShim(
#      54             hf_model,
#      55             mixed_precision=mixed_precision,
#      56             grad_scaler_config=grad_scaler_config,
#      57             config_cls=config_cls,
#      58             model_cls=model_cls,
#      59             tokenizer_cls=tokenizer_cls,
#      60         )
#      61     ],
#      62     dims={"nI": None, "nO": None},
#      63 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/spacy_transformers/layers/hf_shim.py:46, in HFShim.__init__(self, model, config, optimizer, mixed_precision, grad_scaler_config, config_cls, model_cls, tokenizer_cls)
#      38 if "enabled" not in grad_scaler_config:
#      39     grad_scaler_config["enabled"] = mixed_precision
#      41 super().__init__(
#      42     model.transformer,
#      43     config,
#      44     optimizer,
#      45     mixed_precision,
# ---> 46     grad_scaler=PyTorchGradScaler(**grad_scaler_config),
#      47 )
#
# File ~/dissertation/Dissertation-News-Bias/.venv/lib/python3.10/site-packages/thinc/shims/pytorch_grad_scaler.py:54, in PyTorchGradScaler.__init__(self, enabled, init_scale, backoff_factor, growth_factor, growth_interval)
#      51 self._backoff_factor = backoff_factor
#      52 self._growth_interval = growth_interval
# ---> 54 self._growth_tracker = torch.full((1,), 0, dtype=torch.int)
#      55 self._scale = torch.full((1,), init_scale)
#      56 self._found_inf = False
#
# AttributeError: 'NoneType' object has no attribute 'full'
