# %%
from pygooglenews import GoogleNews

gn = GoogleNews(lang= 'en')

# %%
gn_art = gn.search(query = 'NY TIMES')['entries']


for item in gn_art:
    print(item['title'])
# Out:
# Hawaii fires: Maui death toll climbs to 80 - BBC
# Migrant boat sinks in Channel killing six people - BBC
# Islamic State attack on army bus kills 33 Syrian soldiers - BBC
# Perseid meteor shower to light up night sky - BBC
# Special counsel to investigate President Biden's son Hunter - BBC
# Judge Chutkan warns Trump against 'inflammatory' remarks before trial - BBC
# Bibby Stockholm barge migrants moved after Legionella bacteria found - BBC
# Fantasy Premier League: Gambling industry targets FPL players - BBC
# US returns huge haul of stolen artefacts to Italy - BBC
# Rishi Sunak most frequent UK flyer among recent PMs - BBC
# Ukraine war: Crimea bridge targeted by missiles, Russia says - BBC
# Duran Duran's Andy Taylor says cancer drug has given him five more years - BBC
# Amazon asked by minister to justify temporarily withholding sellers' funds - BBC
# Niger coup: Russia warns Ecowas not to take military action - BBC
# ...
